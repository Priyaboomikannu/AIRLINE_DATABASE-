# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyaboomikannu/AIRLINE_DATABASE-/blob/main/1_pandas_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Part 1 – Dataset Understanding
#1.	Import the Pandas library and load the dataset.

import pandas as pd
df=pd.read_csv("/content/uncleaned_airline_dataset_20_columns.csv")
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price  \
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
#2.	Display the first 10 rows of the dataset.
df.head(10)
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
# 5      5   Vistara   UK-945       Delhi        Morning  zero      Afternoon
# 6      6   Vistara   UK-927       Delhi        Morning  zero        Morning
# 7      7   Vistara   UK-951       Delhi      Afternoon  zero        Evening
# 8      8  GO_FIRST   G8-334       Delhi  Early_Morning  zero        Morning
# 9      9  GO_FIRST   G8-336       Delhi      Afternoon  zero        Evening
#
#   destination_city    class  duration  days_left  price  Passenger_Rating  \
# ...

# %%
# 3.	Display the last 10 rows of the dataset.
df.tail(10)
# Out:
#          index    airline  flight source_city departure_time stops  \
# 300143  300143  Air_India  AI-440     Chennai  Early_Morning   one
# 300144  300144  Air_India  AI-539     Chennai        Evening   one
# 300145  300145  Air_India  AI-430     Chennai        Morning   one
# 300146  300146  Air_India  AI-440     Chennai  Early_Morning   one
# 300147  300147  Air_India  AI-569     Chennai  Early_Morning   one
# 300148  300148    Vistara  UK-822     Chennai        Morning   one
# 300149  300149    Vistara  UK-826     Chennai      Afternoon   one
# 300150  300150    Vistara  UK-832     Chennai  Early_Morning   one
# 300151  300151    Vistara  UK-828     Chennai  Early_Morning   one
# 300152  300152    Vistara  UK-822     Chennai        Morning   one
#
#        arrival_time destination_city     class  duration  days_left  price  \
# 300143        Night        Hyderabad  Business     17.42         49  51345
# 300144      Morning        Hyderabad  Business     18.92         49  51345
# ...

# %%
#4.	Find the total number of rows and columns in the dataset.
df.shape
# Out:
# (300153, 20)

# %%
#5.	Display the list of all column names.
df.columns
# Out:
# Index(['index', 'airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price', 'Passenger_Rating', 'Ticket_Type', 'Meal_Option', 'Baggage_kg',
#        'Checkin_Status', 'Airport_Terminal', 'Delay_Minutes', 'Customer_ID'],
#       dtype='object')

# %%
#Part 2 – Dataset Inspection
#6.	Display the data types of all columns.
df.dtypes
# Out:
# index                 int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# Passenger_Rating    float64
# Ticket_Type          object
# Meal_Option          object
# Baggage_kg           object
# Checkin_Status       object
# Airport_Terminal     object
# Delay_Minutes        object
# Customer_ID          object
# dtype: object

# %%
# 7.	Display basic statistical summary of the dataset.
df.describe()
# Out:
#                index       duration      days_left          price  \
# count  300153.000000  300153.000000  300153.000000  300153.000000
# mean   150076.000000      12.221021      26.004751   20889.660523
# std     86646.852011       7.191997      13.561004   22697.767366
# min         0.000000       0.830000       1.000000    1105.000000
# 25%     75038.000000       6.830000      15.000000    4783.000000
# 50%    150076.000000      11.250000      26.000000    7425.000000
# 75%    225114.000000      16.170000      38.000000   42521.000000
# max    300152.000000      49.830000      49.000000  123071.000000
#
#        Passenger_Rating
# count     224988.000000
# mean           3.172458
# std            1.342857
# min            1.000000
# 25%            2.000000
# 50%            4.000000
# 75%            4.000000
# max            5.000000

# %%
# 8. Identify which columns contain missing values.
df.isnull().any()
# Out:
# index               False
# airline             False
# flight              False
# source_city         False
# departure_time      False
# stops               False
# arrival_time        False
# destination_city    False
# class               False
# duration            False
# days_left           False
# price               False
# Passenger_Rating     True
# Ticket_Type          True
# Meal_Option          True
# Baggage_kg           True
# Checkin_Status       True
# Airport_Terminal     True
# Delay_Minutes        True
# Customer_ID          True
# dtype: bool

# %%
#9.	Count the number of missing values in each column.
df.isnull().sum()
# Out:
# index                   0
# airline                 0
# flight                  0
# source_city             0
# departure_time          0
# stops                   0
# arrival_time            0
# destination_city        0
# class                   0
# duration                0
# days_left               0
# price                   0
# Passenger_Rating    75165
# Ticket_Type         60296
# Meal_Option         59825
# Baggage_kg          49689
# Checkin_Status      59611
# Airport_Terminal    49931
# Delay_Minutes       37682
# Customer_ID         49627
# dtype: int64

# %%
#10.	Display the number of unique values in each column.
df.nunique()
# Out:
# index               300153
# airline                  6
# flight                1561
# source_city              6
# departure_time           6
# stops                    3
# arrival_time             6
# destination_city         6
# class                    2
# duration               476
# days_left               49
# price                12157
# Passenger_Rating         5
# Ticket_Type              4
# Meal_Option              4
# Baggage_kg               5
# Checkin_Status           4
# Airport_Terminal         5
# Delay_Minutes            7
# Customer_ID              5
# dtype: int64

# %%
#Part 3 – Data Cleaning (Missing Values)
#11.	Replace missing values in Passenger_Rating with the mean value.
df['Passenger_Rating'].fillna(df['Passenger_Rating'].mean(),inplace=True)
df
# Out:
# /tmp/ipykernel_439/4232200576.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Passenger_Rating'].fillna(df['Passenger_Rating'].mean(),inplace=True)
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# ...

# %%
#12.	Replace missing values in Meal_Option with "Unknown".
df['Meal_Option'].fillna("Unknown",inplace=True)
df
# Out:
# /tmp/ipykernel_439/115137514.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Meal_Option'].fillna("Unknown",inplace=True)
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# ...

# %%
import numpy as np

# %%
#13.	Replace missing values in Baggage_kg with the median value.

df['Baggage_kg'].replace({"30kg":30,"25":25,"15":15},inplace=True)
# Out:
# /tmp/ipykernel_439/835817370.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Baggage_kg'].replace({"30kg":30,"25":25,"15":15},inplace=True)

# %%
df['Baggage_kg'].replace("unknown",np.nan,inplace=True)

# %%
df['Baggage_kg'].fillna(df['Baggage_kg'].median(),inplace=True)

# %%
#14.	Remove rows where Customer_ID is missing.
df.dropna(subset=['Customer_ID'],inplace=True)
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price  \
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
#15.	Verify that missing values are handled.
df.isnull().any()
# Out:
# index               False
# airline             False
# flight              False
# source_city         False
# departure_time      False
# stops               False
# arrival_time        False
# destination_city    False
# class               False
# duration            False
# days_left           False
# price               False
# Passenger_Rating    False
# Ticket_Type          True
# Meal_Option         False
# Baggage_kg          False
# Checkin_Status       True
# Airport_Terminal     True
# Delay_Minutes        True
# Customer_ID         False
# dtype: bool

# %%
#Part 4 – String Cleaning
#16.	Remove leading and trailing spaces from all string columns.
df.columns.str.strip()
# Out:
# Index(['index', 'airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price', 'Passenger_Rating', 'Ticket_Type', 'Meal_Option', 'Baggage_kg',
#        'Checkin_Status', 'Airport_Terminal', 'Delay_Minutes', 'Customer_ID'],
#       dtype='object')

# %%
#17.	Convert Meal_Option values to lowercase.
df['Meal_Option']=df['Meal_Option'].str.lower()
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price  \
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
df["Ticket_Type"].unique()
# Out:
# array([nan, 'Non-Refundable', ' refundable ', 'NON REFUNDABLE',
#        'Refundable'], dtype=object)

# %%
#18.	Convert Ticket_Type values to proper format (Refundable / Non-Refundable).
df['Ticket_Type'] = df['Ticket_Type'].replace({
    'NON REFUNDABLE':'Non-Refundable',
    'refundable':'Refundable',
    ' refundable ':'Refundable'
})

# %%
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price  \
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
#19.	Standardize Checkin_Status values.
df["Checkin_Status"].unique()
# Out:
# array(['Not Checked', 'checked-in', '  checked ', nan, 'Checked-In'],
#       dtype=object)

# %%
df['Checkin_Status'] = df['Checkin_Status'].replace({
    'checked-in':"Checked", '  checked ':"Checked", 'Checked-In':"Checked"
})

# %%
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price  \
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
#20.	Standardize Airport_Terminal values to T1, T2, T3 format.
df["Airport_Terminal"].unique()
# Out:
# array(['T2', nan, 'terminal-2', 'T3', 'T1', 'Terminal 1'], dtype=object)

# %%
df['Airport_Terminal'] = df['Airport_Terminal'].replace({
    'terminal-2':"T1","Terminal 1":"T1"
})

# %%
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price  \
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
df['Passenger_Rating'].fillna(df['Passenger_Rating'].mean(),inplace=True)
df
# Out:
# /tmp/ipykernel_439/4265854534.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Passenger_Rating'].fillna(df['Passenger_Rating'].mean(),inplace=True)
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# ...

# %%
#Part 5 – Data Type Cleaning (5 Questions)
#21.	Convert Passenger_Rating column to numeric datatype.
df['Passenger_Rating'].astype(int)
# Out:
# 0         5
# 1         4
# 2         3
# 3         1
# 4         4
#          ..
# 300148    2
# 300149    1
# 300150    3
# 300151    4
# 300152    2
# Name: Passenger_Rating, Length: 250526, dtype: int64

# %%
# 22.	Convert Baggage_kg values by removing "kg" text.
df["Delay_Minutes"].unique()
# Out:
# array([30., 10., nan,  0.,  5., 15., 60.])

# %%
df["Delay_Minutes"].replace({"30":30,"10":10," 15 ":15,"5":5,"60":60,"0":0},inplace=True)

# %%
#24.	Replace "unknown" values with NaN.
df['Delay_Minutes'].replace('unknown',np.nan,inplace=True)

# %%
df["Baggage_kg"].fillna(df["Baggage_kg"].median(),inplace=True)
# Out:
# /tmp/ipykernel_439/3981878639.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Baggage_kg"].fillna(df["Baggage_kg"].median(),inplace=True)

# %%
df['Delay_Minutes'].fillna(df['Delay_Minutes'].median(),inplace=True)

# %%
#23.	Convert Delay_Minutes column into integer datatype.
df['Delay_Minutes'].astype(int)
# Out:
# 0         30
# 1         10
# 2         10
# 3         10
# 4         10
#           ..
# 300148     0
# 300149    15
# 300150    10
# 300151     5
# 300152    10
# Name: Delay_Minutes, Length: 250526, dtype: int64

# %%
#25.	Verify the updated data types.
print(df.dtypes)
# Out:
# index                 int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# Passenger_Rating    float64
# Ticket_Type          object
# Meal_Option          object
# Baggage_kg           object
# Checkin_Status       object
# Airport_Terminal     object
# Delay_Minutes       float64
# Customer_ID          object
# dtype: object

# %%
#part 6 - Duplicate Data Handling
#26.	Check whether duplicate rows exist in the dataset.
df.duplicated().any()
# Out:
# np.False_

# %%
#27.	Count the number of duplicate rows.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#28.	Remove duplicate rows from the dataset.
df.drop_duplicates()
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price  \
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
# part 7 - Basic Data Analysis
#29.	Find the total number of flights in the dataset.
df['flight'].count()
# Out:
# np.int64(250526)

# %%
#30.	Find the number of unique airlines.
df['airline'].unique()
# Out:
# array(['SpiceJet', 'AirAsia', 'Vistara', 'GO_FIRST', 'Indigo',
#        'Air_India'], dtype=object)

# %%
#31.	Display the list of unique source cities.
df['source_city'].unique()
# Out:
# array(['Delhi', 'Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai'],
#       dtype=object)

# %%
#32.	Display the list of unique destination cities.
df['destination_city'].unique()
# Out:
# array(['Mumbai', 'Bangalore', 'Kolkata', 'Hyderabad', 'Chennai', 'Delhi'],
#       dtype=object)

# %%
#33.	Count flights for each airline.
df.groupby('airline')['flight'].count()
# Out:
# airline
# AirAsia       13402
# Air_India     67465
# GO_FIRST      19368
# Indigo        36105
# SpiceJet       7530
# Vistara      106656
# Name: flight, dtype: int64

# %%
# part 8 - Price Analysis
#34.	Find the average ticket price.
df.groupby('Ticket_Type')['price'].mean()
# Out:
# Ticket_Type
# Non-Refundable    20835.275917
# Refundable        20896.328991
# Name: price, dtype: float64

# %%
#35.	Find the maximum ticket price.
df.groupby('Ticket_Type')['price'].max()
# Out:
# Ticket_Type
# Non-Refundable    117307
# Refundable        116562
# Name: price, dtype: int64

# %%
#36.	Find the minimum ticket price.
df.groupby('Ticket_Type')['price'].min()
# Out:
# Ticket_Type
# Non-Refundable    1105
# Refundable        1105
# Name: price, dtype: int64

# %%
#36.	Find the minimum ticket price.
df.groupby('airline')['price'].min()
# Out:
# airline
# AirAsia      1105
# Air_India    1526
# GO_FIRST     1105
# Indigo       1105
# SpiceJet     1106
# Vistara      1714
# Name: price, dtype: int64

# %%
df['flight'].unique()
# Out:
# array(['SG-8709', 'SG-8157', 'I5-764', ..., '6E-7259', 'AI-433', 'AI-652'],
#       dtype=object)

# %%
#38.	Display the top 5 most expensive flights.
df.groupby('flight')['price'].nlargest(5)
# Out:
# flight
# 0.00E+00  97174       8832
#           100735      7220
#           97470       6092
#           98232       5178
#           98608       5178
#                      ...
# UK-996    230092    114523
#           241548    111964
#           241599    111964
#           230088    105764
#           230089    105764
# Name: price, Length: 7509, dtype: int64

# %%
# part 9 - City Analysis
#39.	Find the number of flights from each source city.
df.groupby('source_city')['flight'].count()
# Out:
# source_city
# Bangalore    43400
# Chennai      32321
# Delhi        51252
# Hyderabad    33995
# Kolkata      38765
# Mumbai       50793
# Name: flight, dtype: int64

# %%
#40.	Find the number of flights to each destination city.
df.groupby('destination_city')['flight'].count()
# Out:
# destination_city
# Bangalore    42789
# Chennai      33733
# Delhi        47760
# Hyderabad    35641
# Kolkata      41396
# Mumbai       49207
# Name: flight, dtype: int64

# %%
#41.	Identify the source city with the most flights.
df.groupby('source_city')['flight'].max()
# Out:
# source_city
# Bangalore    UK-897
# Chennai      UK-838
# Delhi        UK-995
# Hyderabad    UK-898
# Kolkata      UK-778
# Mumbai       UK-996
# Name: flight, dtype: object

# %%
#42.	Find the average ticket price for each source city.
df.groupby('source_city')['price'].min()
# Out:
# source_city
# Bangalore    1603
# Chennai      1105
# Delhi        1998
# Hyderabad    1543
# Kolkata      2436
# Mumbai       1890
# Name: price, dtype: int64

# %%
# part 10 - Flight Details Analysis
#43.	Count flights based on number of stops.
df.groupby('flight')['price'].min()
# Out:
# flight
# 0.00E+00     2201
# 6.00E-102    1755
# 6.00E-105    4079
# 6.00E-113    2201
# 6.00E-121    1543
#              ...
# UK-988       2339
# UK-993       2700
# UK-994       2339
# UK-995       2700
# UK-996       2339
# Name: price, Length: 1555, dtype: int64

# %%
#44.	Find the average price based on flight class.
df.groupby('flight')['stops'].count()
# Out:
# flight
# 0.00E+00       42
# 6.00E-102      33
# 6.00E-105       5
# 6.00E-113      37
# 6.00E-121      19
#              ...
# UK-988       1133
# UK-993        738
# UK-994       1064
# UK-995        836
# UK-996       1070
# Name: stops, Length: 1555, dtype: int64

# %%
#45.	Find the airline with the highest average passenger rating.
df.groupby('airline')['Passenger_Rating'].mean().max()
# Out:
# 3.1834009845158606

# %%
#46.	Count flights based on departure time.
df.groupby('flight')['departure_time'].count()
# Out:
# flight
# 0.00E+00       42
# 6.00E-102      33
# 6.00E-105       5
# 6.00E-113      37
# 6.00E-121      19
#              ...
# UK-988       1133
# UK-993        738
# UK-994       1064
# UK-995        836
# UK-996       1070
# Name: departure_time, Length: 1555, dtype: int64

# %%
# part 11 - Delay Analysis
#47.	Find the average delay minutes of flights.

df.groupby('flight')['Delay_Minutes'].count()
# Out:
# flight
# 0.00E+00       42
# 6.00E-102      33
# 6.00E-105       5
# 6.00E-113      37
# 6.00E-121      19
#              ...
# UK-988       1133
# UK-993        738
# UK-994       1064
# UK-995        836
# UK-996       1070
# Name: Delay_Minutes, Length: 1555, dtype: int64

# %%
#48.	Display flights delayed more than 30 minutes.
df.loc[df['Delay_Minutes'] > 30, ['flight']]
# Out:
#          flight
# 12      6E-5001
# 28      SG-8169
# 33       UK-817
# 34       UK-819
# 37       AI-453
# ...         ...
# 300100   UK-838
# 300106   UK-834
# 300136   UK-834
# 300142   AI-539
# 300145   AI-430
#
# [31318 rows x 1 columns]

# %%
#Part 12 – Final Output (2 Questions)
#50.	Display the final shape of the cleaned dataset.
df.shape
# Out:
# (250526, 20)

# %%
df.isnull().any()
# Out:
# index               False
# airline             False
# flight              False
# source_city         False
# departure_time      False
# stops               False
# arrival_time        False
# destination_city    False
# class               False
# duration            False
# days_left           False
# price               False
# Passenger_Rating    False
# Ticket_Type         False
# Meal_Option         False
# Baggage_kg          False
# Checkin_Status      False
# Airport_Terminal    False
# Delay_Minutes       False
# Customer_ID         False
# dtype: bool

# %%
df['Ticket_Type'].fillna("unknown",inplace=True)
# Out:
# /tmp/ipykernel_439/4000707178.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ticket_Type'].fillna("unknown",inplace=True)

# %%
df['Checkin_Status'].fillna("unknown",inplace=True)
# Out:
# /tmp/ipykernel_439/4060902272.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Checkin_Status'].fillna("unknown",inplace=True)

# %%
df['Airport_Terminal'].fillna("unknown",inplace=True)
# Out:
# /tmp/ipykernel_439/2455131230.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Airport_Terminal'].fillna("unknown",inplace=True)
